# %%
# %sql
create database devlopment.data

# %%
# %sql
create volume devlopment.data.files

# %% [markdown]
#                                                 **DATAFRAME PRACTICAL**

# %%
df= spark.read.csv("/Volumes/devlopment/data/files/orders/orders.csv")

# %%
df.show()

# %%
display(df)

# %%
df= spark.read.csv("/Volumes/devlopment/data/files/orders/orders.csv", header=True)

display(df)

# %%
df.printSchema()

# %%
df= spark.read.csv("/Volumes/devlopment/data/files/orders/orders.csv", header=True,inferSchema=True)

display(df)

# %%
df.printSchema()

# %%
df=spark.read.format("csv").options(header="True",inferSchema=True).load("/Volumes/devlopment/data/files/orders/orders.csv")


display(df.limit(5))

# %%
display(df.select("order_id","order_date","quantity"))

# %%
from pyspark.sql.functions import *

df.select(col('order_id')).show()

# %%
display(df.withColumn('id1',col('order_id')+100).limit(5))

# %%
df.withColumn('state',lit('dfs')).limit(5).show()

# %%
df.withColumn('order_id',col('order_id')-1).show()

# %%
df.withColumnRenamed('product','product_name').show(5)

# %%
df.filter((df.payment_method=='Debit Card') | (df.country =='India')).show()

# %%
df.filter(df.payment_method.startswith('C')).show(5)

# %%
df.filter(df.country.like('%Ind%')).show()

# %%
data = [
    (1,'alice',23),
    (2,'bob',25),
    (3,'charlie',27),
    (4,'david',29),
    (1,'alice',23),
    (2,'bob',25),
    (6,'alice',23)
]
columns = ['id','name','age']
df = spark.createDataFrame(data,columns)
display(df)

# %%
display(df.distinct())
display(df.dropDuplicates())

# %%
display(df.dropDuplicates(["age"]))

# %%
data=[
    (1,'Alice','NY',2000),
    (2,'Bob','CA',3000),
    (3,'Charlie','NY',4000),
    (4,'David','CA',5000),
    (5,'Eve','TX',6000),
    (6,'Frank','TX',7000)
]
columns = ['id','name','state','salary']
df = spark.createDataFrame(data,columns)
display(df)

# %%
display(df.groupBy('state').count())

display(df.groupBy('state').sum('salary'))

# %%
display(df.groupBy('state').sum('salary'))
display(df.groupBy('state').agg({'salary':'sum'}))

# %%
display(df.groupBy('state').avg('salary'))

# %%
emp_data=[
    (1,'Alice',1),
    (2,'Bob',2),    
    (3,'Charlie',3),
    (4,'David',5),
]
columns = ['id','name','dept_id']
emp_df = spark.createDataFrame(emp_data,columns)
display(emp_data)

# %%
dept_data=[
    (1,'IT'),
    (2,'HR'),    
    (3,'Finance'),
    (4,'Marketing'),
]
columns = ['dept_id','dept_name']
dept_df = spark.createDataFrame(dept_data,columns)
display(dept_df)

# %%
emp_df.join(dept_df,emp_df.dept_id==dept_df.dept_id,'inner').show()

# %%
emp_df.join(dept_df,emp_df.dept_id==dept_df.dept_id,'left').show()

# %%
emp_df.join(dept_df,emp_df.dept_id==dept_df.dept_id,'right').show()

# %%
emp_df.join(dept_df,emp_df.dept_id==dept_df.dept_id,'outer').show()

# %%
emp_df.join(dept_df,emp_df.dept_id==dept_df.dept_id,'leftsemi').show()

# %%
emp_df.join(dept_df,emp_df.dept_id==dept_df.dept_id,'left_anti').show()

# %%
from pyspark.sql.types import *
from pyspark.sql import *

# %%
schema=StructType(
    [
        StructField('id',IntegerType(),False), #not nullable
        StructField('name',StringType(),True), # nullable
        StructField('age',IntegerType(),True) # nullable
    ]
)
data=[
    (1,'Alice',30),(2,'Bob',25),
    (3,None,40)
]
df=spark.createDataFrame(data,schema)
display(df)

# %%
schema=StructType(
    [
        StructField('id',IntegerType(),False), #not nullable
        StructField('name',StringType(),True), # nullable
        StructField('age',IntegerType(),True), # nullable
        StructField('salary',IntegerType(),True),
    ]
)

df=spark.read.csv('employee.csv',header= True,schema=schema)
df.show()

# %%
data=[
    ('North','Laptop',10),
    ('North','Phone',20),
    ('South','Laptop',5),
    ('South','Phone',15),
    ('west','Laptop',7),
    ('west','Tablet',3),
]
columns = ['region','product','qty']
df = spark.createDataFrame(data,columns)
display(df)

# %%
df.groupBy('region').pivot('product').sum('qty').show()

# %%
df1=df.groupBy('region').pivot('product').sum('qty')
display(df1)

# %%
from pyspark.sql.functions import expr
df1.select('region',expr("stack(3,'Laptop',Laptop,'Phone',Phone,'Tablet',Tablet) as (product,qty)")).show()

# %%
data=[
    ('Alice','Delhi',10),
    ('Bob','Mumbai',25),
    ('Charlie','Bangalore',60),
    ('David','Pune',None)
]
columns=['name','city','age']
df=spark.createDataFrame(data,columns)
display(df)

# %%
def age_grp(age):
    if age is None:
        return 'Unknown'
    elif age<18:
        return 'Minor'
    elif age >= 18 and age<40:
        return 'Adult'
    else:
        return 'Senior'
age_grp(50)

# %%
from pyspark.sql.functions import udf
from pyspark.sql.types import StringType
age_grp_category=udf(age_grp,StringType())

# %%
df.withColumn('age_cat',age_grp_category(df.age)).show()
